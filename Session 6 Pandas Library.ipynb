# %% [markdown]
# # Pandas Library

# %%
import pandas as pd

# %%
data =pd.read_csv("car.csv")

# %%
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
data.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
data.sample(10)
# Out:
#                                         name  year  selling_price  km_driven  \
# 923                    Maruti Swift ZXI BSIV  2016         670000       7104
# 2165                   Maruti Swift VDI BSIV  2014         390000      90000
# 3917                      Maruti 800 AC Uniq  2005          65000      70000
# 3101                Chevrolet Beat Diesel LS  2014         305000      66000
# 2674  Ford EcoSport 1.5 Petrol Titanium BSIV  2017         800000      19000
# 2134                Tata Indigo CS eLX BS IV  2013         175000      50300
# 1547                  Maruti Swift Dzire VDi  2009         300000      50000
# 2313                        Renault KWID RXT  2016         270000      60000
# 2202                Maruti Wagon R VXI BS IV  2012         200000      90000
# 2615       Fiat Grande Punto Active (Diesel)  2009         125000      95000
#
#         fuel       seller_type transmission         owner
# 923   Petrol  Trustmark Dealer       Manual   First Owner
# ...

# %%
data['selling_price']
# Out:
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4340, dtype: int64

# %%
data.shape
# Out:
# (4340, 8)

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
data.size
# Out:
# 34720

# %%
4340*8
# Out:
# 34720

# %%
df_numerical=data[['year', 'selling_price', 'km_driven']]

# %%
df_numerical.head()
# Out:
#    year  selling_price  km_driven
# 0  2007          60000      70000
# 1  2007         135000      50000
# 2  2012         600000     100000
# 3  2017         250000      46000
# 4  2014         450000     141000

# %%
df_category=data[['name', 'fuel', 'seller_type','transmission', 'owner']]

# %%
df_category.head()
# Out:
#                        name    fuel seller_type transmission         owner
# 0             Maruti 800 AC  Petrol  Individual       Manual   First Owner
# 1  Maruti Wagon R LXI Minor  Petrol  Individual       Manual   First Owner
# 2      Hyundai Verna 1.6 SX  Diesel  Individual       Manual   First Owner
# 3    Datsun RediGO T Option  Petrol  Individual       Manual   First Owner
# 4     Honda Amaze VX i-DTEC  Diesel  Individual       Manual  Second Owner

# %%
# Q.1. selling_price <50000

# %%
data[data['selling_price']<50000]
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 137              Maruti 800 Std  1998          40000      40000  Petrol
# 457          Maruti 800 AC BSII  2001          43000     100000  Petrol
# 877               Tata Nano Std  2011          40000      19000  Petrol
# 1350              Maruti 800 EX  2001          40000      30000  Petrol
# 1468         Tata Nano Cx BSIII  2014          45000       7000  Petrol
# 1711         Maruti 800 AC BSII  2001          45000      72539  Petrol
# 1782            Tata Indica DLE  2006          45000     120000  Diesel
# 1832            Tata Nano LX SE  2012          35000      35000  Petrol
# 2444              Maruti 800 EX  2004          30000      60000  Petrol
# 2495          Ford Ikon 1.4 ZXi  2000          22000      42743  Petrol
# 2662      Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
# 2730               Tata Nano Lx  2010          40000      90000  Petrol
# ...

# %%
#Q.2. Sort the data: km_driven based
data.sort_values(by='km_driven')
# Out:
#                                              name  year  selling_price  \
# 1312                           Mahindra Quanto C6  2014         250000
# 1715                           Ford Figo Titanium  2020         635000
# 1714               Ford Freestyle Titanium Diesel  2020         784000
# 1716            Ford Ecosport 1.5 Diesel Titanium  2020        1000000
# 1291                          Maruti Alto 800 VXI  2020         350000
# ...                                           ...   ...            ...
# 2394          Toyota Innova 2.5 V Diesel 8-seater  2009         350000
# 3679  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2006         400000
# 4184            Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 525             Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 1243                       Maruti Swift VXI BSIII  2009         250000
#
#       km_driven    fuel seller_type transmission           owner
# ...

# %%
#Q.3. Sort the data: year based
data.sort_values(by='year')
# Out:
#                                     name  year  selling_price  km_driven  \
# 3334                  Maruti 800 AC BSII  1992          50000     100000
# 631             Maruti Gypsy E MG410W ST  1995          95000     100000
# 2972                Mahindra Jeep MM 540  1996         200000      60000
# 61              Mahindra Jeep CL 500 MDI  1996         250000      35000
# 1669            Mahindra Jeep CL 500 MDI  1997         150000     120000
# ...                                  ...   ...            ...        ...
# 2137               Maruti Ertiga 1.5 VDI  2020         550000      90000
# 1432    Hyundai Grand i10 Nios AMT Magna  2020         640000       4000
# 1774           Ford Aspire Titanium BSIV  2020         828999       1010
# 176              Maruti Alto K10 LXI CNG  2020         282000      40000
# 3933  Ford Figo Aspire 1.5 TDCi Titanium  2020         530000      45000
#
#         fuel seller_type transmission                 owner
# ...

# %%
#Q.4. Sort the data: km_driven based
data.sort_values(by='km_driven', ascending=False)
# Out:
#                                              name  year  selling_price  \
# 1243                       Maruti Swift VXI BSIII  2009         250000
# 4184            Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 525             Maruti SX4 S Cross DDiS 320 Delta  2016         665000
# 3679  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2006         400000
# 2394          Toyota Innova 2.5 V Diesel 8-seater  2009         350000
# ...                                           ...   ...            ...
# 3703          Ford EcoSport 1.5 Diesel Trend BSIV  2018         841000
# 1715                           Ford Figo Titanium  2020         635000
# 1716            Ford Ecosport 1.5 Diesel Titanium  2020        1000000
# 1714               Ford Freestyle Titanium Diesel  2020         784000
# 1312                           Mahindra Quanto C6  2014         250000
#
#       km_driven    fuel seller_type transmission           owner
# ...

# %% [markdown]
# # Group by in Data

# %%
data.groupby('transmission').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# ...

# %%
data['fuel'].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
# data.groupby('fuel').mean()

# %% [markdown]
# # Merge two dataframe

# %%
data.merge(df_category,on='owner')
# Out:
#                            name_x  year  selling_price  km_driven  fuel_x  \
# 0                   Maruti 800 AC  2007          60000      70000  Petrol
# 1                   Maruti 800 AC  2007          60000      70000  Petrol
# 2                   Maruti 800 AC  2007          60000      70000  Petrol
# 3                   Maruti 800 AC  2007          60000      70000  Petrol
# 4                   Maruti 800 AC  2007          60000      70000  Petrol
# ...                           ...   ...            ...        ...     ...
# 9342721  Honda City i-VTEC CVT ZX  2018        1165000      13000  Petrol
# 9342722  Honda City i-VTEC CVT ZX  2018        1165000      13000  Petrol
# 9342723  Honda City i-VTEC CVT ZX  2018        1165000      13000  Petrol
# 9342724  Honda City i-VTEC CVT ZX  2018        1165000      13000  Petrol
# 9342725  Honda City i-VTEC CVT ZX  2018        1165000      13000  Petrol
#
#         seller_type_x transmission_x           owner  \
# ...

# %%
data.pivot_table(index='fuel',columns='transmission', values='selling_price')
# Out:
# transmission     Automatic         Manual
# fuel
# CNG                    NaN  277174.925000
# Diesel        1.900102e+06  504441.246445
# Electric      3.100000e+05            NaN
# LPG                    NaN  167826.043478
# Petrol        7.664093e+05  302683.221762

# %%
data.pivot_table(index='seller_type',columns='owner', values='km_driven')
# Out:
# owner              First Owner  Fourth & Above Owner  Second Owner  \
# seller_type
# Dealer            52447.438389          85822.500000  60070.844262
# Individual        58496.477249          99475.240506  84628.398980
# Trustmark Dealer  38882.938776                   NaN  47024.500000
#
# owner             Test Drive Car    Third Owner
# seller_type
# Dealer                    4155.0   74859.444444
# Individual                   NaN  100050.288136
# Trustmark Dealer             NaN            NaN

# %%
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %% [markdown]
# # Handling missing Values

# %%
data.dropna()
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
data.fillna(value=0)
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
# data.fillna(data.mean())

# %%
t=data['selling_price'][0:10]
print(t)
# Out:
# 0     60000
# 1    135000
# 2    600000
# 3    250000
# 4    450000
# 5    140000
# 6    550000
# 7    240000
# 8    850000
# 9    365000
# Name: selling_price, dtype: int64

# %%
data['selling_price']=data['selling_price'].astype(str)

# %%
t=data['selling_price'][0]
print(type(t))
# Out:
# <class 'str'>

# %%
data['selling_price']=data['selling_price'].astype(int)

# %%
t=data['selling_price'][0]
print(type(t))
# Out:
# <class 'numpy.int32'>

# %% [markdown]
# # Apply function

# %%
def reverse_name(name):
    return name[::-1]

# %%
reverse_name("Sachin")
# Out:
# 'nihcaS'

# %%
name="Techlang is Data Science"
name[::-1]
# Out:
# 'ecneicS ataD si gnalhceT'

# %%
data['transmission']=data['transmission'].apply(reverse_name)

# %%
data.sample(20)
# Out:
#                                              name  year  selling_price  \
# 1032                            Hyundai i10 Magna  2012         229999
# 3731                Volkswagen Vento 1.6 Highline  2015         509999
# 2197        Mahindra Scorpio VLX 2WD ABS AT BSIII  2009         360000
# 2806               Tata Indica Vista Quadrajet VX  2012         130000
# 2213                      Honda BR-V i-DTEC VX MT  2016         910000
# 2257                      Audi A4 3.0 TDI Quattro  2013        1580000
# 3013             Tata New Safari DICOR 2.2 EX 4x2  2009         150000
# 1313  Toyota Innova 2.5 G (Diesel) 8 Seater BS IV  2009         450000
# 1893                           Maruti Wagon R VXI  2005         100000
# 1189                  Hyundai Xcent 1.1 CRDi Base  2015         375000
# 400                       Mahindra Supro VX 8 Str  2017         500000
# 2073         Mahindra Scorpio SLX 2.6 Turbo 8 Str  2007         190000
# ...

# %%
data.to_csv('output_session6.csv')

# %%
data.to_excel('output_Session6.xlsx',sheet_name='Sheet1')

# %% [markdown]
# # statistics

# %%
data.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
data['year'].mean()
# Out:
# 2013.0907834101383

# %%
data.plot()
# Out:
# <Axes: >

# %%
# data.plot(kind='bar')

# %% [markdown]
# # Indexing and Selection

# %%
# Indexing and Selection
data.loc[0]
# Out:
# name             Maruti 800 AC
# year                      2007
# selling_price            60000
# km_driven                70000
# fuel                    Petrol
# seller_type         Individual
# transmission            launaM
# owner              First Owner
# Name: 0, dtype: object

# %%
data.iloc[0:10,0:2]
